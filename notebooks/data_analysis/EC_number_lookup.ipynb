# %%
EC_NUMBER_LIST_PATH = '../../data/ECNumbers.csv'
EC_NUMBER = '1.1.5'

# %% [markdown]
# # EC Number Lookup

# %%
import pandas as pd

# %%
df = pd.read_csv(EC_NUMBER_LIST_PATH, sep='\t')

# %%
df
# Out:
#     ECNumber  Level_1 Level_2 Level_3 Level_4  \
# 0      1.-.-        1       -       -       -
# 1      1.1.-        1       1       -       -
# 2      1.1.1        1       1       1       -
# 3      1.1.2        1       1       2       -
# 4      1.1.3        1       1       3       -
# 5      1.1.4        1       1       4       -
# 6      1.1.5        1       1       5       -
# 7      1.1.9        1       1       9       -
# 8     1.1.98        1       1      98       -
# 9     1.1.99        1       1      99       -
# 10     1.2.-        1       2       -       -
# 11     1.2.1        1       2       1       -
# 12     1.2.2        1       2       2       -
# 13     1.2.3        1       2       3       -
# 14     1.2.4        1       2       4       -
# 15     1.2.5        1       2       5       -
# 16     1.2.7        1       2       7       -
# 17    1.2.98        1       2      98       -
# 18    1.2.99        1       2      99       -
# ...
